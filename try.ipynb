# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage

gen_image= np.random.random([300,300])
print(gen_image.min(),gen_image.max())
plt.imshow(gen_image)
# Out:
# 2.226723139719944e-05 0.9999919558355217
